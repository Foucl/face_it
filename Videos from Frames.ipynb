# %% [markdown]
# # Stimulus Generation: Videos from Frames
#
# Loop over scrambled and triangled frames and stick them together. For convenience, repeat the first frame 11 times, so we get the desired timings.

# %%
# <api>
# %load_ext jupyter_cms
# %matplotlib inline
# Out:
# None

# %%
# <api>
import os
import sys

import numpy as np
from matplotlib import pyplot as plt

import cv2
from skimage import io
from sklearn.feature_extraction import image
from skimage.util.shape import view_as_blocks
import itertools

import mywb.face_detection as fd
import mywb.face_scrambling as fs

# %%
frame_dir = './all_frames_scrambled_triangled/'
movie_dir = './scrambled_vids/'
stimuli = os.listdir(frame_dir)

test_dir = './all_frames_scrambled_triangled/frames_ekl99m03/'

# %%
from moviepy.editor import ImageSequenceClip

def generate_movie(source_dir, target_file, durs=None, verbose=True):
    if not durs:
        durs = [0.41] + [1/30.] * 17
    clip = ImageSequenceClip(source_dir, durations=durs)
    clip.fps=30
    clip.write_videofile(target_file, codec='mpeg4', audio=False, write_logfile=True, verbose=verbose)
    return clip
target_file = './scrambled_vids/ekl99m03.mp4'
clip = generate_movie(test_dir, target_file, verbose=False)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 45.52it/s]

# %%
clip.ipython_display(height=500)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 59.52it/s]
# <div align=middle><video height='500'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
for stim in stimuli:
    source_dir = os.path.join(frame_dir, stim)
    target_file = os.path.join(movie_dir, stim.split('_')[1] + '.mp4')
    generate_movie(source_dir, target_file)
# Out:
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m03.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m03.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 59.76it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m03.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m05.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m05.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 30.06it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m05.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m07.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m07.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:01<00:00, 27.96it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m07.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m09.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m09.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 23.26it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m09.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m10.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m10.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 67.26it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m10.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m15.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m15.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 52.17it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m15.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m20.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m20.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 52.54it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m20.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m21.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m21.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 51.37it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m21.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m23.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m23.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 41.49it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m23.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m24.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m24.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 47.85it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m24.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m25.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m25.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 31.89it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m25.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m28.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m28.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 42.55it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m28.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m30.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m30.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 60.48it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m30.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m33.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m33.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 58.48it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m33.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m36.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m36.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 48.94it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m36.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m38.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m38.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 52.26it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m38.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m46.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m46.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 59.88it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m46.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m47.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m47.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 58.82it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m47.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m49.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m49.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 41.10it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m49.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99m71.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99m71.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 34.64it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99m71.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99w01.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99w01.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 37.64it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99w01.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99w02.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99w02.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 52.91it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99w02.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99w04.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99w04.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 52.36it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99w04.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99w08.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99w08.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 59.88it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99w08.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99w12.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99w12.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 47.69it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ./scrambled_vids/ekl99w12.mp4
#
# [MoviePy] >>>> Building video ./scrambled_vids/ekl99w14.mp4
# [MoviePy] Writing video ./scrambled_vids/ekl99w14.mp4
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00