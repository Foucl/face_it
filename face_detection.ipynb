# %% [markdown]
# # Stimulus Generation: Face Detection

# %% [markdown]
# The problem: Generate 'Scrambled Faces' as control stimuli like in [Rayson, Bonaiuto, Ferrari, & Murray (2016)](http://www.sciencedirect.com/science/article/pii/S1878929315301067):
# > The scrambled versions of each video were produced by dividing the face region into square blocks (18 × 18 pixels), randomly shuffling these blocks in the first frame of the video, and then applying the same transformation to each subsequent frame.
#
# Using the ADFES database, their frames look like this:
# <img src="./rayson_large.JPG" width="200px" height="222px" />
#
# We need to apply the same concept to the videos generated from the RaFD. The process solving this problem appears to have six steps:
#
# 1. extract frame from video
# 2. find face area in first frame
# 3. generate grid of 18px x 18xp (or, rather, 17x17, see below) blocks in that area
# 4. randomize position of each block in the grid
# 5. apply 3 & 4 to remaining frames
# 6. add gradually appearing triangle (indicating response mapping) to movement frames
# 7. create video from manipulated frames
#
# This notebook deals with Steps 1 and 2. Aside from some adjustments necessary for 'non-typical' identities, these steps can be considered done.
#
# This is all done in Python. First, a number of modules need to be imported, most importantly OpenCV (cv2), which does most of the heavy lifting. facemorpher is a module that offers a nice interface to the STASM algorithm that does the facial feature extraction.

# %%
# <help>

# %%
# <api>
# %matplotlib inline

import os
import math

import numpy as np
from matplotlib import pyplot as plt

import cv2
from facemorpher import locator # we should get rid of this in the future and interface a STASM binary directly via system call
from skimage import io
from sklearn.feature_extraction import image
from skimage.util.shape import view_as_blocks
import itertools

# %% [markdown]
# ## Step 1: Extract the first frame
# For now, we will only extract the first frame of each video. Extracting the other 17 is trivial.

# %%
# <api>
def extract_frames(vid, img='auto', n_max=1):
    bn = os.path.basename(vid)
    bn = os.path.splitext(bn)[0]
    vid_folder = os.path.dirname(vid)
    vid_folder_par = os.path.dirname(vid_folder)
    vidcap = cv2.VideoCapture(vid)
    success, image = vidcap.read()
    if img == 'auto':
        toggle_auto=True
    else:
        toggle_auto=False
    n = 1
    while success and n <= n_max:
        if toggle_auto:
            out_dir = os.path.join(vid_folder_par, 'all_frames', 'frames_' + bn)
            img = os.path.join(out_dir, bn + '_frame_' + '%02d' % n + '.jpg')
            print img
        out_dir = os.path.dirname(img)   
        if not os.path.exists(out_dir):
            os.makedirs(out_dir)    
        cv2.imwrite(img, image)
        success, image = vidcap.read()
        n += 1
    return success, img

# %%
vid = './vid/ekl99m03.avi'
print bn
extract_frames(vid, img='./test.jpg', n_max=1)
# Out:
# ekl99m03
# (True, './test.jpg')

# %%
def batch_extract_first_frame(vid_dir, img_dir):
    n = 0
    vid_list = os.listdir(vid_dir)
    for f in vid_list:
        bn = os.path.splitext(f)[0]
        img = os.path.join(img_dir, bn + '_frame_1.jpg')
        # print "extracting first frame from ", f
        vid = os.path.join(vid_dir, f)
        success = extract_frames(vid, img, n_max=1)
        if success:
            n += 1
    print "%d of %d videos successfully converted" % (n, len(vid_list))

vid_dir = './vid'
img_dir = './img'
batch_extract_first_frame(vid_dir, img_dir)
# Out:
# 78 of 78 videos successfully converted

# %% [markdown]
# This works just the way it should:
# <img src="./img/ekl99m09_frame_1.jpg" width="200px" height="222px" />
#
#
# ## Step 2: Find Facial Area in images
# ### Step 2.1: Choosing an Algorithm for Facial Feature Extraction
#
# This problem is much more challenging to solve in an automatic manner. A number of algorithms for detecting facial features is available. I have tried STASM ([Milborrow & Nicolls, 2014](http://www.milbo.org/stasm-files/active-shape-models-with-sift-and-mars.pdf)), which uses Active Shape Models, and one by [Kazemi & Sullivan (2014)](http://www.csc.kth.se/~vahidk/papers/KazemiCVPR14.pdf) employing regression trees and realized in C++'s [dlib library](http://dlib.net/).
#
# I finally decided against the latter, as it does not detect the hairline or any other features on the forehead:
# <img src="http://www.csc.kth.se/~vahidk/images/facereg.jpg" width="200px" height="222px" />
#
# STASM on the other hand generates 79 points, most of which mark the contours of a face, including three points for the hairline:

# %%
# <api>
def stasm_demo(img='./img/fre99m30_frame_1.jpg', conv_hull=False):
    points = locator.face_points(img, add_boundary_points=False)
    im = cv2.imread(img)
    
    if cv2.__version__[0] == '3': # taking care of changed cv-API
        outcol = cv2.COLOR_BGR2RGB
        lt = cv2.LINE_AA
    else:
        outcol = cv2.cv.CV_BGR2RGB
        lt = cv2.CV_AA
    
    if conv_hull:
        hull = cv2.convexHull(points)
        cv2.polylines(im, [hull], True, (155,0,0), thickness=1, lineType=lt)
        
    for point in points:
        cv2.circle(im, (point[0], point[1]), 3, (0,0,155), thickness=1, lineType=lt)
    

    im = cv2.cvtColor(im, outcol)
    return im

def simple_implot(im, crop=(110, 440, 70, 360), figsize=(6,6)):
    if crop:
        y,h,x,w = crop
        im = im[y:y+h, x:x+w]
    plt.figure(figsize=figsize)
    plt.axis('off')
    plt.imshow(im)
    plt.show()
    if plt.get_backend()[0] == 'Q':
        mng = plt.get_current_fig_manager()
        mng.window.setGeometry(2200,100,768, 511)

# %%
im = stasm_demo()
simple_implot(im)

# %% [markdown]
# ### Step 2.2: Find Face Area
#
# This proved a little difficult for at least two reasons: **First**, the position of STASM's three 'hairline points' is quite inacurrate (at least their height). Quite often, they are too low. **Second**, it is not enough to just connect the outer points. OpenCVs `convexHull` function does that.

# %%
# <help:face_detect_stasm>
im = stasm_demo(img='./img/fre99w22_frame_1.jpg', conv_hull=True)
simple_implot(im)

# %% [markdown]
# Rather, to get as close as possible to the 'egg' shape of a typical face, I merge two ellipses. To see how this works, look at the specific distribution of some points returned by STASM:
#
# ![stasm_loc](./stasm_loc.jpg)
#
# I first find the line connecting point 0 and point 12 (called `left_`and `right_center_point` in the code below), as well as point 6 (`chin`) and 14 (`forehead_tip`). Those two axes yield a central point (`center`) that is in close proximity to point 52 (`nosetip`). The bottom ellipse is generated with this point as the center and the length of the axes as its diameter (the 'narrower' part of the face-egg). The top ellipse is moved up a bit, the vertical diameter stretched and the horizontal diameter compressed (the 'wider' part of an egg).
#
# The function right now looks like this:

# %%
# <api>
def annotate_face(img='./img/fre99m36_frame_1.jpg', y_offset=50):
    
    if cv2.__version__[0] == '3': # taking care of changed cv-API
        outcol = cv2.COLOR_BGR2RGB
        lt = cv2.LINE_AA
    else:
        outcol = cv2.cv.CV_BGR2RGB
        lt = cv2.CV_AA
    
    im = cv2.imread(img)
    im_orig = im.copy()
    points = locator.face_points(img)
    
    nosetip = points[52]
    left_center_point = points[0]
    right_center_point = points[12]
    chin = points[6]
    forehead_tip = points[14]
    
    width = right_center_point[0] - left_center_point[0] + 5
    center_x = (right_center_point[0] + left_center_point[0]) / 2
    
    height = chin[1] - forehead_tip[1]
    center_y = (chin[1] + forehead_tip[1]) / 2
    
    center = [center_x, center_y]
    
    el_bottom = cv2.ellipse2Poly((center_x, center_y), (width/2, height/2), 0,0,360,4)
    el_top = cv2.ellipse2Poly((center_x, center_y - 25), ((width/2) + 5, (height/2)-10), 0,0,360,4)
    el_total = cv2.convexHull(np.vstack([el_top, el_bottom]))
    
    cv2.polylines(im, np.int32([el_bottom]), True, (10,200,200), thickness=2, lineType=lt)
    cv2.polylines(im, np.int32([el_top]), True, (255,255,255), thickness=2, lineType=lt)
    cv2.polylines(im, el_total, True, (0,0,233), thickness=6, lineType=lt)
    
    for point in points[0:16]:
        cv2.circle(im, (point[0], point[1]), 3, (100,55,55), thickness=1)
    cv2.circle(im, (nosetip[0], nosetip[1]), 3, (100,55,55), thickness=2, lineType=lt)
    cv2.circle(im, (center_x, center_y), 3, (0,0,233), thickness=2, lineType=lt)
        
    im = cv2.cvtColor(im, outcol)
    
    return im

def get_stasm_el(img='./img/fre99m36_frame_1.jpg', y_offset=50):
    im = io.imread(img)
    points = locator.face_points(img)
    
    nosetip = points[52]
    left_center_point = points[0]
    right_center_point = points[12]
    chin = points[6]
    forehead_tip = points[14]
    
    width = right_center_point[0] - left_center_point[0] + 5
    center_x = (right_center_point[0] + left_center_point[0]) / 2
    
    height = chin[1] - forehead_tip[1]
    center_y = (chin[1] + forehead_tip[1]) / 2
    
    center = [center_x, center_y]
    
    el_bottom = cv2.ellipse2Poly((center_x, center_y), (width/2, height/2), 0,0,360,4)
    el_top = cv2.ellipse2Poly((center_x, center_y - 25), ((width/2) + 5, (height/2)-10), 0,0,360,4)
    el = cv2.convexHull(np.vstack([el_top, el_bottom]))
    
    return im, el

# %% [markdown]
# The code below demonstrates this approach. The red dotted circle is the 'egg' - the combination (or outer envelop) of the bottom ellipsis (yellow) an the top one (white). The red dot is the centerpoint of the bottom ellipse, the blue one is point 52 found by STASM, what the algorithm considers the tip of the nose. As you can see, this approach does not work well with all identities.

# %%
# <api>
def batch_plot(im_dir='./img', func=annotate_face,func2=None, n_rows=4, n_cols=5, setp=2, crop=(110, 440, 70, 360)):
    img_flist = os.listdir('./img')
    n_rows = 4
    n_cols = 5
    step = 2
    plt.figure(figsize=(n_cols*3,n_rows*6))
    for i in xrange(n_rows*n_cols):
        im_idx = i * step
        try:
            im, shape = func(os.path.join(im_dir,img_flist[im_idx]))
        except:
            im = func(os.path.join(im_dir,img_flist[im_idx]))
        if func2:
            try:
                im = func2(im, shape)
            except:
                im = func2(im)
        #if len(im) > 1: # for functions that return more than just the image
         #   im = im[0]
        if crop:
            y,h,x,w = crop
            im = im[y:y+h, x:x+w]
        plt.subplot(n_rows,n_cols, i + 1)
        plt.axis('off')
        plt.imshow(im)
        plt.text(4, 20, img_flist[im_idx], fontsize=10)

    # adjust whitespace between subplots
    left, right, bottom, top = 0.125, 0.9, 0.5, 1
    wspace, hspace = 0.02, 0.02
    plt.subplots_adjust(left, bottom, right, top, wspace, hspace)

# %%
# <help:face_detect_batch>
#batch_plot(func=get_stasm_el, func2=shuffle_blocks)
batch_plot()

# %% [markdown]
# One identity (w14) poses a special problem as she is the only one were hair covers a considerable part of the forehead. Here we will need to adjust the facial area manually as the automatic solution does not look very well:

# %%
im = annotate_face('./img/fre99w14_frame_1.jpg')
simple_implot(im)

# %% [markdown]
# Below are some more helper functions:
# - `get_window` finds the 'window', meaning the oval shape the faces appear in - its location is hardwired
# - `paint_ellipse`simply draws the given shape on the given image

# %%
# <api>

def get_window(img='./img/fre99m36_frame_1.jpg', factor=1, size='large', backend='skimage'):
       
    if backend=='skimage':
        im = io.imread(img)
    else:
        im = cv2.imread(img)
        
    y_offset = 50
    x, y = 504/2, 768/2-y_offset
    
    if size == 'large':
        ax1, ax2 = 280*factor, 375*factor
    elif size == 'medium':
        ax1, ax2 = 275*factor, 370*factor
    elif size == 'small':
        ax1, ax2 = 250*factor, 360*factor
    else:
        raise ValueError("size " + str(size) + " not recognized")
    
    el = cv2.ellipse2Poly((x,y), (int(ax1)/2, int(ax2)/2), 0,0,360,4)
    
    return im, el

def paint_ellipse(im, el, color=(10,200,200), thickness=2):
    
    if cv2.__version__[0] == '3': # taking care of changed cv-API
        outcol = cv2.COLOR_BGR2RGB
        lt = cv2.LINE_AA
    else:
        outcol = cv2.cv.CV_BGR2RGB
        lt = cv2.CV_AA

    cv2.polylines(im, np.int32([el]), True, color, thickness=thickness, lineType=lt)
        
    im = cv2.cvtColor(im, outcol)
    
    return im

# %% [markdown]
# ## Return to Step 1 - extract all frames and store them in folders
# --> move this to another notebook?

# %%
def batch_extract_all_frames(vid_dir):
    vid_list = os.listdir(vid_dir)
    n = 0
    for f in vid_list:
        bn = os.path.splitext(f)[0]
        vid = os.path.join(vid_dir, f)
        success = extract_frames(vid, n_max=18)
        if success:
            n += 1
    print "%d of %d videos successfully converted" % (n, len(vid_list))

# %%
batch_extract_all_frames(vid_dir)
# Out:
# .\all_frames\frames_ekl99m03\ekl99m03_frame_01.jpg
# .\all_frames\frames_ekl99m03\ekl99m03_frame_02.jpg
# .\all_frames\frames_ekl99m03\ekl99m03_frame_03.jpg
# .\all_frames\frames_ekl99m03\ekl99m03_frame_04.jpg
# .\all_frames\frames_ekl99m03\ekl99m03_frame_05.jpg
# .\all_frames\frames_ekl99m03\ekl99m03_frame_06.jpg
# .\all_frames\frames_ekl99m03\ekl99m03_frame_07.jpg
# .\all_frames\frames_ekl99m03\ekl99m03_frame_08.jpg
# .\all_frames\frames_ekl99m03\ekl99m03_frame_09.jpg
# .\all_frames\frames_ekl99m03\ekl99m03_frame_10.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_02.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_03.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_04.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_05.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_06.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_07.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_08.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_09.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_10.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_11.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_12.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_13.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_14.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_15.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_16.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_17.jpg
# .\all_frames\frames_ekl99m23\ekl99m23_frame_18.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_01.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_02.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_03.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_04.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_05.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_06.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_07.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_08.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_09.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_10.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_11.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_12.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_13.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_14.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_15.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_16.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_17.jpg
# .\all_frames\frames_ekl99m24\ekl99m24_frame_18.jpg
# .\all_frames\frames_ekl99m25\ekl99m25_frame_01.jpg
# .\all_frames\frames_ekl99m25\ekl99m25_frame_02.jpg
# .\all_frames\frames_ekl99m25\ekl99m25_frame_03.jpg
# .\all_frames\frames_ekl99m25\ekl99m25_frame_04.jpg
# .\all_frames\frames_ekl99m25\ekl99m25_frame_05.jpg
# .\all_frames\frames_ekl99m25\ekl99m25_frame_06.jpg
# .\all_frames\frames_ekl99m25\ekl99m25_frame_07.jpg
# .\all_frames\frames_ekl99m25\ekl99m25_frame_08.jpg
# .\all_frames\frames_ekl99m25\ekl99m25_frame_09.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_04.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_05.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_06.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_07.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_08.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_09.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_10.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_11.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_12.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_13.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_14.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_15.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_16.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_17.jpg
# .\all_frames\frames_fre99w08\fre99w08_frame_18.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_01.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_02.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_03.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_04.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_05.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_06.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_07.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_08.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_09.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_10.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_11.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_12.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_13.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_14.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_15.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_16.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_17.jpg
# .\all_frames\frames_fre99w12\fre99w12_frame_18.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_01.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_02.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_03.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_04.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_05.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_06.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_07.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_08.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_09.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_10.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_11.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_12.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_13.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_14.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_15.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_16.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_17.jpg
# .\all_frames\frames_fre99w14\fre99w14_frame_18.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_01.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_02.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_03.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_04.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_05.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_06.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_07.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_08.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_09.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_10.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_11.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_12.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_13.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_14.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_15.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_16.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_17.jpg
# .\all_frames\frames_fre99w16\fre99w16_frame_18.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_01.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_02.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_03.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_04.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_05.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_06.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_07.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_08.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_09.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_10.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_11.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_12.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_13.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_14.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_15.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_16.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_17.jpg
# .\all_frames\frames_fre99w18\fre99w18_frame_18.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_01.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_02.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_03.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_04.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_05.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_06.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_07.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_08.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_09.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_10.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_11.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_12.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_13.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_14.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_15.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_16.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_17.jpg
# .\all_frames\frames_fre99w19\fre99w19_frame_18.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_01.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_02.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_03.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_04.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_05.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_06.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_07.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_08.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_09.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_10.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_11.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_12.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_13.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_14.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_15.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_16.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_17.jpg
# .\all_frames\frames_fre99w22\fre99w22_frame_18.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_01.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_02.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_03.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_04.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_05.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_06.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_07.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_08.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_09.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_10.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_11.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_12.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_13.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_14.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_15.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_16.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_17.jpg
# .\all_frames\frames_fre99w26\fre99w26_frame_18.jpg
# .\all_frames\frames_fre99w27\fre99w27_frame_01.jpg
# .\all_frames\frames_fre99w32\fre99w32_frame_14.jpg
# .\all_frames\frames_fre99w32\fre99w32_frame_15.jpg
# .\all_frames\frames_fre99w32\fre99w32_frame_16.jpg
# .\all_frames\frames_fre99w32\fre99w32_frame_17.jpg
# .\all_frames\frames_fre99w32\fre99w32_frame_18.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_01.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_02.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_03.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_04.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_05.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_06.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_07.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_08.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_09.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_10.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_11.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_12.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_13.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_14.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_15.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_16.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_17.jpg
# .\all_frames\frames_fre99w37\fre99w37_frame_18.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_01.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_02.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_03.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_04.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_05.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_06.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_07.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_08.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_09.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_10.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_11.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_12.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_13.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_14.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_15.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_16.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_17.jpg
# .\all_frames\frames_fre99w56\fre99w56_frame_18.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_01.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_02.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_03.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_04.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_05.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_06.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_07.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_08.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_09.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_10.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_11.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_12.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_13.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_14.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_15.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_16.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_17.jpg
# .\all_frames\frames_fre99w57\fre99w57_frame_18.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_01.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_02.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_03.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_04.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_05.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_06.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_07.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_08.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_09.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_10.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_11.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_12.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_13.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_14.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_15.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_16.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_17.jpg
# .\all_frames\frames_fre99w58\fre99w58_frame_18.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_01.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_02.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_03.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_04.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_05.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_06.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_07.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_08.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_09.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_10.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_11.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_12.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_13.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_14.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_15.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_16.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_17.jpg
# .\all_frames\frames_fre99w61\fre99w61_frame_18.jpg
# 78 of 78 videos successfully converted
